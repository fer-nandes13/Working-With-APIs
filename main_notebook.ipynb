# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
free_pc_games = requests.get("https://www.freetogame.com/api/games?platform=pc")
print("free_pc_games:", free_pc_games.status_code)
# Out:
# free_pc_games: 200

# %%
#print(free_pc_games.text)

# %%
response = requests.get("https://www.freetogame.com/api/games?platform=pc")
response
results = response.json()
results
# Out:
# [{'id': 540,
#   'title': 'Overwatch 2',
#   'thumbnail': 'https://www.freetogame.com/g/540/thumbnail.jpg',
#   'short_description': 'A hero-focused first-person team shooter from Blizzard Entertainment.',
#   'game_url': 'https://www.freetogame.com/open/overwatch-2',
#   'genre': 'Shooter',
#   'platform': 'PC (Windows)',
#   'publisher': 'Activision Blizzard',
#   'developer': 'Blizzard Entertainment',
#   'release_date': '2022-10-04',
#   'freetogame_profile_url': 'https://www.freetogame.com/overwatch-2'},
#  {'id': 521,
#   'title': 'Diablo Immortal',
#   'thumbnail': 'https://www.freetogame.com/g/521/thumbnail.jpg',
#   'short_description': 'Built for mobile and also released on PC, Diablo Immortal fills in the gaps between Diablo II and III in an MMOARPG environment.',
#   'game_url': 'https://www.freetogame.com/open/diablo-immortal',
#   'genre': 'MMOARPG',
#   'platform': 'PC (Windows)',
#   'publisher': 'Blizzard Entertainment',
#   'developer': 'Blizzard Entertainment',
# ...

# %%
#pd.set_option("display.max_rows")

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#     id                title                                       thumbnail  \
# 0  540          Overwatch 2  https://www.freetogame.com/g/540/thumbnail.jpg
# 1  521      Diablo Immortal  https://www.freetogame.com/g/521/thumbnail.jpg
# 2  517             Lost Ark  https://www.freetogame.com/g/517/thumbnail.jpg
# 3  516  PUBG: BATTLEGROUNDS  https://www.freetogame.com/g/516/thumbnail.jpg
# 4  508             Enlisted  https://www.freetogame.com/g/508/thumbnail.jpg
# 5  525          MultiVersus  https://www.freetogame.com/g/525/thumbnail.jpg
# 6  475       Genshin Impact  https://www.freetogame.com/g/475/thumbnail.jpg
# 7  523            Fall Guys  https://www.freetogame.com/g/523/thumbnail.jpg
# 8   11          Neverwinter   https://www.freetogame.com/g/11/thumbnail.jpg
# 9  515        Halo Infinite  https://www.freetogame.com/g/515/thumbnail.jpg
#
#                                    short_description  \
# 0  A hero-focused first-person team shooter from ...
# ...

# %%
results = response.json()
flattened_data = json_normalize(results)

flattened_data
# Out:
# C:\Users\Startklar\AppData\Local\Temp\ipykernel_23536\3501564835.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results)
#       id                         title  \
# 0    540                   Overwatch 2
# 1    521               Diablo Immortal
# 2    517                      Lost Ark
# 3    516           PUBG: BATTLEGROUNDS
# 4    508                      Enlisted
# ..   ...                           ...
# 315  335               Ragnarok Online
# 316   17             Entropia Universe
# 317  336                Anarchy Online
# 318  251  The Lord of the Rings Online
# 319  339                         Tibia
#
#                                           thumbnail  \
# 0    https://www.freetogame.com/g/540/thumbnail.jpg
# 1    https://www.freetogame.com/g/521/thumbnail.jpg
# 2    https://www.freetogame.com/g/517/thumbnail.jpg
# 3    https://www.freetogame.com/g/516/thumbnail.jpg
# ...

# %%
import requests

# %%
import json
from pandas.io.json import json_normalize

# %%
game_stores = requests.get("https://www.cheapshark.com/api/1.0/stores")

# %%
print("game_stores:", game_stores.status_code)
# Out:
# game_stores: 200

# %%
print(game_stores.text)
# Out:
# [{"storeID":"1","storeName":"Steam","isActive":1,"images":{"banner":"\/img\/stores\/banners\/0.png","logo":"\/img\/stores\/logos\/0.png","icon":"\/img\/stores\/icons\/0.png"}},{"storeID":"2","storeName":"GamersGate","isActive":1,"images":{"banner":"\/img\/stores\/banners\/1.png","logo":"\/img\/stores\/logos\/1.png","icon":"\/img\/stores\/icons\/1.png"}},{"storeID":"3","storeName":"GreenManGaming","isActive":1,"images":{"banner":"\/img\/stores\/banners\/2.png","logo":"\/img\/stores\/logos\/2.png","icon":"\/img\/stores\/icons\/2.png"}},{"storeID":"4","storeName":"Amazon","isActive":0,"images":{"banner":"\/img\/stores\/banners\/3.png","logo":"\/img\/stores\/logos\/3.png","icon":"\/img\/stores\/icons\/3.png"}},{"storeID":"5","storeName":"GameStop","isActive":0,"images":{"banner":"\/img\/stores\/banners\/4.png","logo":"\/img\/stores\/logos\/4.png","icon":"\/img\/stores\/icons\/4.png"}},{"storeID":"6","storeName":"Direct2Drive","isActive":0,"images":{"banner":"\/img\/stores\/banners\/5.png
# ...

# %%
response = requests.get("https://www.cheapshark.com/api/1.0/stores")
#response_2
data = pd.DataFrame(response.json())
data.head()
#data.shape
# Out:
#   storeID       storeName  isActive  \
# 0       1           Steam         1
# 1       2      GamersGate         1
# 2       3  GreenManGaming         1
# 3       4          Amazon         0
# 4       5        GameStop         0
#
#                                               images
# 0  {'banner': '/img/stores/banners/0.png', 'logo'...
# 1  {'banner': '/img/stores/banners/1.png', 'logo'...
# 2  {'banner': '/img/stores/banners/2.png', 'logo'...
# 3  {'banner': '/img/stores/banners/3.png', 'logo'...
# 4  {'banner': '/img/stores/banners/4.png', 'logo'...

# %%
results_2 = response.json()
flattened_data_2 = json_normalize(results_2)

flattened_data_2
# Out:
# C:\Users\Startklar\AppData\Local\Temp\ipykernel_23536\1878402498.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data_2 = json_normalize(results_2)
#    storeID         storeName  isActive               images.banner  \
# 0        1             Steam         1   /img/stores/banners/0.png
# 1        2        GamersGate         1   /img/stores/banners/1.png
# 2        3    GreenManGaming         1   /img/stores/banners/2.png
# 3        4            Amazon         0   /img/stores/banners/3.png
# 4        5          GameStop         0   /img/stores/banners/4.png
# 5        6      Direct2Drive         0   /img/stores/banners/5.png
# 6        7               GOG         1   /img/stores/banners/6.png
# 7        8            Origin         1   /img/stores/banners/7.png
# 8        9         Get Games         0   /img/stores/banners/8.png
# 9       10        Shiny Loot         0   /img/stores/banners/9.png
# ...

# %%
game_give_aways = requests.get("https://www.gamerpower.com/api/giveaways")

# %%
print("game_give_aways:", game_give_aways.status_code)
# Out:
# game_give_aways: 200

# %%
print(game_give_aways.text)
# Out:
# [{"id":2653,"title":"Styx: Shards of Darkness (GOG) Giveaway","worth":"$19.99","thumbnail":"https:\/\/www.gamerpower.com\/offers\/1\/655cd527ef3d9.jpg","image":"https:\/\/www.gamerpower.com\/offers\/1b\/655cd527ef3d9.jpg","description":"Download Styx: Shards of Darkness without spending a penny via GOG! Styx: Shards of Darkness is a stealth game with huge multi-layered sandbox environments and a new array of lethal abilities. Check it out!","instructions":"1. Click the \"Go to giveaway\" green button and you will be redirected to the GOG home page\r\n2. Scroll down until you find the game banner.\r\n3. Click the \"Get it Free\" button and login into your GOG account to unlock the game.","open_giveaway_url":"https:\/\/www.gamerpower.com\/open\/styx-shards-of-darkness-gog-giveaway","published_date":"2023-11-21 11:04:56","type":"Game","platforms":"PC, GOG","end_date":"2023-11-24 23:59:00","users":1680,"status":"Active","gamerpower_url":"https:\/\/www.gamerpower.com\/styx-shards-of-darkn
# ...

# %%
response = requests.get("https://www.gamerpower.com/api/giveaways")
#response_2
data_3 = pd.DataFrame(response.json())
data_3.head()
#data.shape
# Out:
#      id                                          title   worth  \
# 0  2653        Styx: Shards of Darkness (GOG) Giveaway  $19.99
# 1  2651        League of Angels: Pact - Free Gift Keys     N/A
# 2  2649                Earthlock (Epic Games) Giveaway  $29.99
# 3  2648  Surviving the Aftermath (Epic Games) Giveaway  $29.99
# 4  2647      World of Warships: Steam Anniversary Pack     N/A
#
#                                            thumbnail  \
# 0  https://www.gamerpower.com/offers/1/655cd527ef...
# 1  https://www.gamerpower.com/offers/1/655767754b...
# 2  https://www.gamerpower.com/offers/1/65564119b4...
# 3  https://www.gamerpower.com/offers/1/65564116a0...
# 4  https://www.gamerpower.com/offers/1/6556307b88...
#
#                                                image  \
# 0  https://www.gamerpower.com/offers/1b/655cd527e...
# 1  https://www.gamerpower.com/offers/1b/655767754...
# 2  https://www.gamerpower.com/offers/1b/65564119b...
# ...

# %%
results_3 = response.json()
flattened_data_3 = json_normalize(results_3)

flattened_data_3
# Out:
# C:\Users\Startklar\AppData\Local\Temp\ipykernel_23536\2996583133.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data_3 = json_normalize(results_3)
#        id                                              title   worth  \
# 0    2653            Styx: Shards of Darkness (GOG) Giveaway  $19.99
# 1    2651            League of Angels: Pact - Free Gift Keys     N/A
# 2    2649                    Earthlock (Epic Games) Giveaway  $29.99
# 3    2648      Surviving the Aftermath (Epic Games) Giveaway  $29.99
# 4    2647          World of Warships: Steam Anniversary Pack     N/A
# ..    ...                                                ...     ...
# 118    25   Brawlhalla Katars of the Raven Weapon Skin Codes     N/A
# 119     9                           Free Rocket League Codes     N/A
# 120     7                       Destiny 2: Free Emblem Codes     N/A
# ...
